# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.experimental import enable_iterative_imputer
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler
from sklearn.impute import IterativeImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

# %%
df = pd.read_csv("phones-v1.csv")

# %%
df["Price Range"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Price Range'>

# %%
df["Brand"].unique()
# Out:
# array(['Apple', 'Samsung', 'Xiaomi'], dtype=object)

# %%
df = pd.concat([df, pd.get_dummies(df["Brand"])], axis=1)
df = df.drop(columns=["Brand"])

# %%
df["Model"].unique()
# Out:
# array(['Apple iPhone X', 'Samsung Galaxy S9+', 'Samsung Galaxy S9', nan,
#        'Apple iPhone XS Max', 'Apple iPhone XS', 'Apple iPhone XR',
#        'Samsung Galaxy S10e', 'Samsung Galaxy S10+', 'Samsung Galaxy S10',
#        'Samsung Galaxy Note10+', 'Apple iPhone 11', 'Apple iPhone 11 Pro',
#        'Apple iPhone 11 Pro Max', 'Samsung Galaxy A51',
#        'Samsung Galaxy A71', 'Xiaomi Mi 10 5G', 'Samsung Galaxy S20 5G',
#        'Samsung Galaxy S20 Ultra 5G', 'Samsung Galaxy S20+ 5G',
#        'Apple iPhone SE (2020)', 'Samsung Galaxy A31',
#        'Samsung Galaxy A51 5G', 'Xiaomi Redmi Note 9S',
#        'Samsung Galaxy M11', 'Xiaomi Redmi Note 9 Pro',
#        'Xiaomi Mi Note 10 Lite', 'Xiaomi Redmi Note 9',
#        'Xiaomi Poco F2 Pro', 'Xiaomi Redmi 9', 'Samsung Galaxy A71 5G',
#        'Xiaomi Redmi 9A', 'Xiaomi Redmi 9C', 'Samsung Galaxy Note20 5G',
#        'Samsung Galaxy Note20 Ultra 5G', 'Xiaomi Poco X3 NFC',
#        'Samsung Galaxy S20 FE 5G', 'Xiaomi Mi 10T Pro 5G',
#        'Apple iPhone 12', 'Apple iPhone 12 Pro', 'Samsung Galaxy A42 5G',
#        'Apple iPhone 12 mini', 'Apple iPhone 12 Pro Max',
#        'Xiaomi Poco M3', 'Samsung Galaxy A12', 'Xiaomi Mi 11',
#        'Samsung Galaxy A02s', 'Xiaomi Redmi Note 9T', 'Xiaomi Redmi 9T',
#        'Samsung Galaxy A32 5G', 'Samsung Galaxy A02',
#        'Samsung Galaxy S21 5G', 'Samsung Galaxy S21+ 5G',
#        'Samsung Galaxy S21 Ultra 5G', 'Samsung Galaxy A32',
#        'Xiaomi Redmi Note 10', 'Samsung Galaxy A52 5G',
#        'Xiaomi Poco X3 Pro', 'Xiaomi Redmi Note 10 Pro',
#        'Samsung Galaxy A52', 'Samsung Galaxy A72', 'Xiaomi Poco F3',
#        'Xiaomi Mi 11 Pro', 'Xiaomi Mi 11 Lite', 'Xiaomi Mi 11 Lite 5G',
#        'Xiaomi Redmi Note 10 5G', 'Xiaomi Redmi Note 10S',
#        'Samsung Galaxy M12', 'Xiaomi Poco M3 Pro 5G',
#        'Samsung Galaxy Tab A7 Lite', 'Samsung Galaxy A22 5G',
#        'Samsung Galaxy M32', 'Samsung Galaxy A22',
#        'Samsung Galaxy A12 Nacho', 'Samsung Galaxy A03s',
#        'Xiaomi Poco X3 GT', 'Xiaomi Redmi 10',
#        'Samsung Galaxy Z Fold3 5G', 'Samsung Galaxy Z Flip3 5G',
#        'Samsung Galaxy A52s 5G', 'Apple iPhone 13 mini',
#        'Apple iPhone 13 Pro Max', 'Apple iPhone 13',
#        'Apple iPhone 13 Pro', 'Xiaomi 11 Lite 5G NE',
#        'Samsung Galaxy M52 5G', 'Xiaomi 11T Pro', 'Xiaomi 11T',
#        'Xiaomi Redmi Note 11 Pro+ 5G', 'Xiaomi Poco M4 Pro 5G',
#        'Xiaomi Redmi Note 11 4G', 'Samsung Galaxy A13 5G',
#        'Xiaomi 12 Pro', 'Xiaomi 12', 'Xiaomi 12X',
#        'Samsung Galaxy S21 FE 5G', 'Samsung Galaxy A03',
#        'Xiaomi Redmi Note 11', 'Xiaomi Redmi Note 11S',
#        'Xiaomi Redmi Note 11 Pro', 'Xiaomi Redmi Note 11 Pro 5G',
#        'Samsung Galaxy S22 5G', 'Samsung Galaxy S22+ 5G',
#        'Samsung Galaxy S22 Ultra 5G', 'Xiaomi Poco M4 Pro',
#        'Apple iPhone SE (2022)', 'Samsung Galaxy A13', 'Xiaomi Redmi 10C',
#        'Xiaomi Poco X4 Pro 5G', 'Samsung Galaxy A53 5G',
#        'Samsung Galaxy A23', 'Xiaomi Redmi 10A', 'Samsung Galaxy M33',
#        'Samsung Galaxy A33 5G', 'Samsung Galaxy M53',
#        'Samsung Galaxy A73 5G', 'Xiaomi Redmi Note 11S 5G',
#        'Xiaomi Poco F4 GT', 'Xiaomi Redmi 10 2022', 'Xiaomi Poco C40',
#        'Xiaomi Poco X4 GT', 'Xiaomi Poco F4', 'Samsung Galaxy M13',
#        'Samsung Galaxy A13 (SM-A137)', 'Samsung Galaxy Z Flip4',
#        'Samsung Galaxy Z Fold4', 'Samsung Galaxy A23 5G',
#        'Xiaomi Poco M5s', 'Xiaomi Poco M5', 'Apple iPhone 14',
#        'Apple iPhone 14 Pro', 'Apple iPhone 14 Pro Max',
#        'Samsung Galaxy A04s', 'Xiaomi Redmi A1+', 'Xiaomi Redmi 10 5G',
#        'Xiaomi 12T Pro', 'Xiaomi 12T', 'Apple iPhone 14 Plus',
#        'Xiaomi Poco M4 5G', 'Samsung Galaxy A04',
#        'Xiaomi Redmi Note 12 Pro', 'Xiaomi Redmi Note 12 Pro+',
#        'Samsung Galaxy A04e', 'Xiaomi 13', 'Xiaomi 13 Pro',
#        'Xiaomi Redmi 12C', 'Xiaomi Redmi Note 12',
#        'Samsung Galaxy A14 5G', 'Xiaomi Poco X5 Pro', 'Xiaomi Poco X5',
#        'Samsung Galaxy S23', 'Samsung Galaxy S23+',
#        'Samsung Galaxy S23 Ultra', 'Xiaomi 13 Lite', 'Samsung Galaxy A34',
#        'Samsung Galaxy A54', 'Xiaomi Redmi A2+', 'Xiaomi Redmi A2',
#        'Samsung Galaxy A14', 'Xiaomi Redmi Note 12 4G',
#        'Xiaomi Redmi Note 12 Pro 4G', 'Xiaomi 13 Ultra',
#        'Xiaomi Redmi Note 12S', 'Xiaomi Poco F5 Pro', 'Xiaomi Poco F5',
#        'Samsung Galaxy A24 4G', 'Xiaomi Redmi 12', 'Xiaomi Redmi 12 5G',
#        'Samsung Galaxy Z Fold5', 'Samsung Galaxy Z Flip5',
#        'Xiaomi Redmi Note 13 Pro', 'Xiaomi Redmi Note 13 Pro+',
#        'Apple iPhone 15', 'Apple iPhone 15 Pro Max',
#        'Apple iPhone 15 Plus', 'Apple iPhone 15 Pro', 'Xiaomi 13T Pro',
#        'Xiaomi 13T', 'Samsung Galaxy S23 FE', 'Samsung Galaxy A05',
#        'Samsung Galaxy Tab S9 FE+', 'Samsung Galaxy Tab S9 FE',
#        'Samsung Galaxy A05s', 'Xiaomi 14', 'Xiaomi Poco C65',
#        'Xiaomi Redmi 13C', 'Samsung Galaxy A15', 'Samsung Galaxy A25',
#        'Samsung Galaxy A15 5G', 'Xiaomi Redmi 13C 5G',
#        'Xiaomi Redmi Note 13', 'Xiaomi Poco X6', 'Xiaomi Poco X6 Pro',
#        'Xiaomi Poco M6 Pro', 'Xiaomi Redmi Note 13 Pro 4G',
#        'Xiaomi Redmi Note 13 4G', 'Xiaomi 14 Ultra', 'Xiaomi Redmi A3',
#        'Samsung Galaxy A35', 'Samsung Galaxy A55', 'Samsung Galaxy M55',
#        'Samsung Galaxy M15', 'Xiaomi Poco F6 Pro', 'Xiaomi Poco F6',
#        'Xiaomi Redmi A3x', 'Xiaomi Redmi 13', 'Xiaomi Poco M6 4G',
#        'Xiaomi Mix Flip', 'Samsung Galaxy A06', 'Xiaomi Redmi 14C',
#        'Apple iPhone 16 Pro', 'Apple iPhone 16', 'Apple iPhone 16 Plus',
#        'Apple iPhone 16 Pro Max', 'Xiaomi 14T', 'Xiaomi 14T Pro'],
#       dtype=object)

# %%
df = df.drop(columns=["Model"])

# %%
df.head()
# Out:
#    Storage (GB)  RAM (GB)      Launch  \
# 0           256         3  2017-11-03
# 1           256         3  2017-11-03
# 2            64         6  2018-03-01
# 3           128         6  2018-03-01
# 4           256         6  2018-03-01
#
#                                       Dimensions  Weight (g) Display Type  \
# 0  143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)       174.0         OLED
# 1  143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)       174.0         OLED
# 2  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)       189.0       AMOLED
# 3  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)       189.0       AMOLED
# 4  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)       189.0       AMOLED
#
#    Display Size       OS   NFC  Battery (mAh)        CPU  Year  PPI Density  \
# 0           5.8      iOS  True         2716.0  Hexa-Core  2017          458
# 1           5.8      iOS  True         2716.0  Hexa-Core  2017          458
# 2           6.2  Android  True         3500.0  Octa-Core  2018          529
# 3           6.2  Android  True         3500.0  Octa-Core  2018          529
# 4           6.2  Android  True         3500.0  Octa-Core  2018          529
#
#     Price Range  Apple  Samsung  Xiaomi
# 0    high price   True    False   False
# 1     low price   True    False   False
# 2     low price  False     True   False
# 3  medium price  False     True   False
# 4    high price  False     True   False

# %%
df["Launch"].unique().shape
# Out:
# (148,)

# %%
df = df.drop(columns=["Launch"])

# %%
def preprocess_dimensions(value):
    if not pd.isna(value):
        values = value.split(" mm")[0].split(" x ")
        return [float(value) for value in values]
    return value

# %%
df[["Height", "Width", "Thickness"]] = df["Dimensions"].apply(preprocess_dimensions).tolist()

# %%
df = df.drop(columns=["Dimensions"])

# %%
df.head()
# Out:
#    Storage (GB)  RAM (GB)  Weight (g) Display Type  Display Size       OS  \
# 0           256         3       174.0         OLED           5.8      iOS
# 1           256         3       174.0         OLED           5.8      iOS
# 2            64         6       189.0       AMOLED           6.2  Android
# 3           128         6       189.0       AMOLED           6.2  Android
# 4           256         6       189.0       AMOLED           6.2  Android
#
#     NFC  Battery (mAh)        CPU  Year  PPI Density   Price Range  Apple  \
# 0  True         2716.0  Hexa-Core  2017          458    high price   True
# 1  True         2716.0  Hexa-Core  2017          458     low price   True
# 2  True         3500.0  Octa-Core  2018          529     low price  False
# 3  True         3500.0  Octa-Core  2018          529  medium price  False
# 4  True         3500.0  Octa-Core  2018          529    high price  False
#
#    Samsung  Xiaomi  Height  Width  Thickness
# 0    False   False   143.6   70.9        7.7
# 1    False   False   143.6   70.9        7.7
# 2     True   False   158.1   73.8        8.5
# 3     True   False   158.1   73.8        8.5
# 4     True   False   158.1   73.8        8.5

# %%
df["Display Type"].unique()
# Out:
# array(['OLED', 'AMOLED', 'LCD'], dtype=object)

# %%
df = pd.concat([df, pd.get_dummies(df["Display Type"])], axis=1)
df = df.drop(columns=["Display Type"])

# %%
df.head()
# Out:
#    Storage (GB)  RAM (GB)  Weight (g)  Display Size       OS   NFC  \
# 0           256         3       174.0           5.8      iOS  True
# 1           256         3       174.0           5.8      iOS  True
# 2            64         6       189.0           6.2  Android  True
# 3           128         6       189.0           6.2  Android  True
# 4           256         6       189.0           6.2  Android  True
#
#    Battery (mAh)        CPU  Year  PPI Density   Price Range  Apple  Samsung  \
# 0         2716.0  Hexa-Core  2017          458    high price   True    False
# 1         2716.0  Hexa-Core  2017          458     low price   True    False
# 2         3500.0  Octa-Core  2018          529     low price  False     True
# 3         3500.0  Octa-Core  2018          529  medium price  False     True
# 4         3500.0  Octa-Core  2018          529    high price  False     True
#
#    Xiaomi  Height  Width  Thickness  AMOLED    LCD   OLED
# 0   False   143.6   70.9        7.7   False  False   True
# 1   False   143.6   70.9        7.7   False  False   True
# 2   False   158.1   73.8        8.5    True  False  False
# 3   False   158.1   73.8        8.5    True  False  False
# 4   False   158.1   73.8        8.5    True  False  False

# %%
df["OS"].unique()
# Out:
# array(['iOS', 'Android'], dtype=object)

# %%
df = pd.concat([df, pd.get_dummies(df["OS"])], axis=1)

# %%
df = df.drop(columns=["OS"])

# %%
df["NFC"] = df["NFC"].astype(int)

# %%
df["CPU"] = df["CPU"].map({"Quad-Core": 4, "Hexa-Core": 6, "Octa-Core": 8})

# %%
ordinal_encoder = OrdinalEncoder(
    categories=[["low price", "medium price", "high price"]],
    handle_unknown="use_encoded_value",
    unknown_value=np.nan,
)

# %%
df[["Price Range"]] = ordinal_encoder.fit_transform(df[["Price Range"]])

# %%
df.head()
# Out:
#    Storage (GB)  RAM (GB)  Weight (g)  Display Size  NFC  Battery (mAh)  CPU  \
# 0           256         3       174.0           5.8    1         2716.0    6
# 1           256         3       174.0           5.8    1         2716.0    6
# 2            64         6       189.0           6.2    1         3500.0    8
# 3           128         6       189.0           6.2    1         3500.0    8
# 4           256         6       189.0           6.2    1         3500.0    8
#
#    Year  PPI Density  Price Range  ...  Samsung  Xiaomi  Height  Width  \
# 0  2017          458          2.0  ...    False   False   143.6   70.9
# 1  2017          458          0.0  ...    False   False   143.6   70.9
# 2  2018          529          0.0  ...     True   False   158.1   73.8
# 3  2018          529          1.0  ...     True   False   158.1   73.8
# 4  2018          529          2.0  ...     True   False   158.1   73.8
#
#    Thickness  AMOLED    LCD   OLED  Android    iOS
# 0        7.7   False  False   True    False   True
# 1        7.7   False  False   True    False   True
# 2        8.5    True  False  False     True  False
# 3        8.5    True  False  False     True  False
# 4        8.5    True  False  False     True  False
#
# [5 rows x 21 columns]

# %%
cols = ["Battery (mAh)", "Display Size", "CPU", "Apple", "Height", "Thickness", "OLED", "Android", "iOS"]

# %%
iterative_imputer = IterativeImputer()

# %%
df[cols] = iterative_imputer.fit_transform(df[cols])

# %%
df.isnull().sum()
# Out:
# Storage (GB)      0
# RAM (GB)          0
# Weight (g)        0
# Display Size      0
# NFC               0
# Battery (mAh)     0
# CPU               0
# Year              0
# PPI Density       0
# Price Range      15
# Apple             0
# Samsung           0
# Xiaomi            0
# Height            0
# Width             0
# Thickness         0
# AMOLED            0
# LCD               0
# OLED              0
# Android           0
# iOS               0
# dtype: int64

# %%
df.dropna(subset=["Price Range"], axis=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Storage (GB)     0
# RAM (GB)         0
# Weight (g)       0
# Display Size     0
# NFC              0
# Battery (mAh)    0
# CPU              0
# Year             0
# PPI Density      0
# Price Range      0
# Apple            0
# Samsung          0
# Xiaomi           0
# Height           0
# Width            0
# Thickness        0
# AMOLED           0
# LCD              0
# OLED             0
# Android          0
# iOS              0
# dtype: int64

# %%
X, y = df.drop(columns=["Price Range"]), df["Price Range"]

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.2)

# %%
scaler = MinMaxScaler()

# %%
train_X = scaler.fit_transform(train_X)

# %%
test_X = scaler.transform(test_X)

# %%
classifier = LogisticRegression().fit(train_X, train_y)

# %%
pred_y = classifier.predict(test_X)

# %%
print(classification_report(test_y, pred_y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.16      0.25        19
#          1.0       0.82      0.95      0.88       159
#          2.0       0.40      0.18      0.25        22
#
#     accuracy                           0.79       200
#    macro avg       0.61      0.43      0.46       200
# weighted avg       0.75      0.79      0.75       200

# %%
classifier = DecisionTreeClassifier().fit(train_X, train_y)

# %%
pred_y = classifier.predict(test_X)

# %%
print(classification_report(test_y, pred_y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.43      0.47      0.45        19
#          1.0       0.86      0.84      0.85       159
#          2.0       0.39      0.41      0.40        22
#
#     accuracy                           0.76       200
#    macro avg       0.56      0.58      0.57       200
# weighted avg       0.77      0.76      0.76       200

# %%
param_grid = {
    "criterion": ["entropy", "gini"],
    "max_depth": [None, 1, 2, 3, 4],
}

# %%
classifier = DecisionTreeClassifier()

# %%
grid_search = GridSearchCV(
    classifier,
    param_grid,
    scoring="f1_weighted",
    cv=5,
)

# %%
grid_search.fit(train_X, train_y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [None, 1, 2, 3, 4]},
#              scoring='f1_weighted')

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 4}

# %%
pred_y = grid_search.predict(test_X)

# %%
print(classification_report(test_y, pred_y))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.45      0.26      0.33        19
#          1.0       0.84      0.92      0.88       159
#          2.0       0.56      0.41      0.47        22
#
#     accuracy                           0.80       200
#    macro avg       0.62      0.53      0.56       200
# weighted avg       0.78      0.80      0.78       200
